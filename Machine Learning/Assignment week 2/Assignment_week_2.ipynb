# %%
from google.colab import drive
drive.mount('/content/drive/MyDrive/MAI/Machine Learning/Assignment week 2')

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/MyDrive/4c16-labs/code/lab-06/

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive
# !git clone https://nicolasquintanaariste:$GITHUB_TOKEN@github.com/nicolasquintanaariste/MAI.git
# %cd MAI
# Out:
# /content/gdrive/MyDrive
# fatal: destination path 'MAI' already exists and is not an empty directory.
# /content/gdrive/MyDrive/MAI
