# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %cd /content/gdrive/MyDrive/MAI

# !git add .

# !git config --global user.name "Nicolas Quintana"
# !git config --global user.email "your_email@example.com"
# Out:
# Mounted at /content/gdrive

# %%
# !git commit -m ""

# %%
# !git push

# %%
# Out:
# /content/gdrive/MyDrive
# fatal: destination path 'MAI' already exists and is not an empty directory.
# /content/gdrive/MyDrive/MAI

# %%
# !git config --global user.name "Nicolas Quintana"
# !git config --global user.email "your_email@example.com"

# !git commit -m "Added Dissertation and Machine learning folders"
# Out:
# [main (root-commit) c10a0e3] Added Dissertation and Machine learning folders
#  3 files changed, 2 insertions(+)
#  create mode 100644 Dissertation/Data_DaynNight_0.ipynb
#  create mode 100644 Machine Learning/Assignment week 2/Assignment_week_2.ipynb
#  create mode 100644 Machine Learning/Assignment week 2/week2_questions.pdf

# %%
# !git push
# Out:
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (8/8), 382.12 KiB | 2.96 MiB/s, done.
# Total 8 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/nicolasquintanaariste/MAI.git
#  * [new branch]      main -> main
