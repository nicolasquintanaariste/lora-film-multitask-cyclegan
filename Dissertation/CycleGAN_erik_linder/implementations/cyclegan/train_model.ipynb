# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/MAI/Dissertation/CycleGAN by Erik Linder Noren/"
# !sudo pip3 install -r requirements.txt
# Out:
# Mounted at /content/drive
# [Errno 2] No such file or directory: '/content/drive/MyDrive/MAI/Dissertation/CycleGAN by Erik Linder Noren/'
# /content
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# %cd "/content/drive/MyDrive/MAI/Dissertation/CycleGAN_erik_linder/implementations/cyclegan"
# !python cyclegan.py --dataset_name monet2photo --n_cpu 2 --batch_size 2 --img_height 128 --img_width 128
# Out:
# /content/drive/MyDrive/MAI/Dissertation/CycleGAN_erik_linder/implementations/cyclegan
# Namespace(epoch=0, n_epochs=200, dataset_name='monet2photo', batch_size=2, lr=0.0002, b1=0.5, b2=0.999, decay_epoch=100, n_cpu=2, img_height=128, img_width=128, channels=3, sample_interval=100, checkpoint_interval=-1, n_residual_blocks=9, lambda_cyc=10.0, lambda_id=5.0)
# /content/drive/MyDrive/MAI/Dissertation/CycleGAN_erik_linder/implementations/cyclegan/cyclegan.py:171: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /pytorch/torch/csrc/tensor/python_tensor.cpp:78.)
#   valid = Variable(Tensor(np.ones((real_A.size(0), *D_A.output_shape))), requires_grad=False)
# [Epoch 0/200] [Batch 1182/3144] [D loss: 0.209663] [G loss: 5.171217, adv: 0.785461, cycle: 0.294317, identity: 0.288516] ETA: 2 days, 5:59:15.944510Traceback (most recent call last):
# ...
