# %% [markdown]
# # **Mount drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Git**

# %%
# %cd /content/drive/MyDrive/MAI
# !git remote set-url origin https://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@github.com/nicolasquintanaariste/MAI.git
# Out:
# /content/drive/MyDrive/MAI

# %% [markdown]
# ## Pulling

# %%
# %cd "/content/drive/MyDrive/MAI"

# !git pull https://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@github.com/nicolasquintanaariste/MAI.git
# Out:
# /content/drive/MyDrive/MAI
# From https://github.com/nicolasquintanaariste/MAI
#  * branch            HEAD       -> FETCH_HEAD
# Already up to date.

# %% [markdown]
# ## Pushing

# %%
# %%writefile /content/drive/MyDrive/MAI/.gitignore
# # Ignore all files in the data folder
# Dissertation/CycleGAN_erik_linder/data/
#
# # Ignore all images in the cyclegan images folder
# Dissertation/CycleGAN_erik_linder/implementations/cyclegan/images/
#
# Dissertation/images/
# Dissertation/saved_models
#
# Machine Learning/
#
# data/
# Out:
# Overwriting /content/drive/MyDrive/MAI/.gitignore

# %%
# %cd "/content/drive/MyDrive/MAI"

# !git add .

# !git status
# !git diff --name-only --cached

# !git config --global user.name "Nicolas Quintana"
# !git config --global user.email "nicolas.quintana.ariste@gmail.com"
# Out:
# /content/drive/MyDrive/MAI
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   .gitignore
# 	modified:   .vscode/launch.json
# 	modified:   Dissertation/CycleGAN_erik_linder/implementations/cyclegan/train_model.ipynb
# 	new file:   Dissertation/CycleGAN_erik_linder/requirements.txt
#
# .gitignore
# .vscode/launch.json
# Dissertation/CycleGAN_erik_linder/implementations/cyclegan/train_model.ipynb
# Dissertation/CycleGAN_erik_linder/requirements.txt

# %%
# !git commit -m "added gitignore"
# Out:
# [main 8da3932] added gitignore
#  4 files changed, 19 insertions(+), 40 deletions(-)
#  create mode 100644 .gitignore
#  rewrite .vscode/launch.json (100%)
#  rewrite Dissertation/CycleGAN_erik_linder/implementations/cyclegan/train_model.ipynb (94%)
#  create mode 100644 Dissertation/CycleGAN_erik_linder/requirements.txt

# %%
# !git push
# Out:
# Everything up-to-date

# %%
# %cd "/content/drive/MyDrive/MAI/Dissertation/CycleGAN_erik_linder/implementations/cyclegan"

# !python evaluation.py \
    --folder1 "/content/drive/MyDrive/MAI/Dissertation/CycleGAN_erik_linder/data/day2night/train/A" \
    --folder2 "/content/drive/MyDrive/MAI/Dissertation/CycleGAN_erik_linder/data/day2night/test/A"
# Out:
# /content/drive/MyDrive/MAI/Dissertation/CycleGAN_erik_linder/implementations/cyclegan
# FID score: 93.04192352294922

# %% [markdown]
# # **Install requirements**

# %%
# %cd "/content/drive/MyDrive/MAI/Machine Learning/Final-assignment/math-bool-GPTs/"
# !sudo pip3 install -r requirements.txt
# Out:
# /content/drive/MyDrive/MAI/Dissertation/CycleGAN_erik_linder
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# # **Train**

# %%
# %cd "/content/drive/MyDrive/MAI/Machine Learning/Final-assignment/math-bool-GPTs/math_GPT"

# !python gpt.py
# Out:
# /content/drive/MyDrive/MAI/Dissertation/CycleGAN_erik_linder/implementations/cyclegan
# Namespace(epoch=0, n_epochs=100, dataset_name='day2night', batch_size=4, lr=0.0002, b1=0.5, b2=0.999, decay_epoch=25, n_cpu=2, img_height=128, img_width=128, channels=3, sample_interval=100, checkpoint_interval=-1, n_residual_blocks=6, lambda_cyc=10.0, lambda_id=5.0)
# CUDA available: True
# /content/drive/MyDrive/MAI/Dissertation/CycleGAN_erik_linder/implementations/cyclegan/cyclegan.py:172: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /pytorch/torch/csrc/tensor/python_tensor.cpp:78.)
#   valid = Variable(Tensor(np.ones((real_A.size(0), *D_A.output_shape))), requires_grad=False)
# [Epoch 67/100] [Batch 34/107] [D loss: 0.222411] [G loss: 2.230216, adv: 0.376529, cycle: 0.127571, identity: 0.115595] ETA: 0:27:26.353147

# %% [markdown]
# # **Evaluation**

# %%
# !pip install torchmetrics
# !pip install torch-fidelity

# %%
# %cd "/content/drive/MyDrive/MAI/Dissertation/CycleGAN_erik_linder/implementations/cyclegan"

# !python evaluation.py \
    --folder1 "/content/drive/MyDrive/MAI/Dissertation/CycleGAN_erik_linder/data/day2night/train/A" \
    --folder2 "/content/drive/MyDrive/MAI/Dissertation/CycleGAN_erik_linder/data/day2night/train/B"
# Out:
# /content/drive/MyDrive/MAI/Dissertation/CycleGAN_erik_linder/implementations/cyclegan
# Downloading: "https://github.com/toshas/torch-fidelity/releases/download/v0.2.0/weights-inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/weights-inception-2015-12-05-6726825d.pth
# 100% 91.2M/91.2M [00:00<00:00, 169MB/s]
# FID score: 149.3775177001953

# %% [markdown]
# # **Splitting data (chatGPTed)**

# %%
# %cd "/content/drive/MyDrive/MAI/Dissertation/CycleGAN_erik_linder/data"
# !unzip -q "archive (2).zip" -d .
# Out:
# /content/drive/MyDrive/MAI/Dissertation/CycleGAN_erik_linder/data

# %%
import os
import shutil
import random

# Paths
data_dir = "/content/drive/MyDrive/MAI/Dissertation/CycleGAN_erik_linder/data/day2night"
output_dir = "/content/drive/MyDrive/MAI/Dissertation/CycleGAN_erik_linder/data/day2night"

day_dir = os.path.join(data_dir, "day")
night_dir = os.path.join(data_dir, "night")

# Train/test split ratio
train_ratio = 0.8

# Create output folders
for split in ["train", "test"]:
    for subfolder in ["A", "B"]:  # A = day, B = night
        os.makedirs(os.path.join(output_dir, split, subfolder), exist_ok=True)

def split_and_copy(src_dir, dest_dir_a, dest_dir_b, ratio=0.8):
    files = [f for f in os.listdir(src_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    random.shuffle(files)
    split_idx = int(len(files) * ratio)

    # Train files
    for f in files[:split_idx]:
        shutil.copy(os.path.join(src_dir, f), os.path.join(dest_dir_a if 'day' in src_dir else dest_dir_b, f))
    # Test files
    for f in files[split_idx:]:
        shutil.copy(os.path.join(src_dir, f), os.path.join(dest_dir_b if 'night' in src_dir else dest_dir_a, f))

# Copy day images to train/test A folders
day_train_dir = os.path.join(output_dir, "train", "A")
day_test_dir = os.path.join(output_dir, "test", "A")
split_and_copy(day_dir, day_train_dir, day_test_dir, ratio=train_ratio)

# Copy night images to train/test B folders
night_train_dir = os.path.join(output_dir, "train", "B")
night_test_dir = os.path.join(output_dir, "test", "B")
split_and_copy(night_dir, night_train_dir, night_test_dir, ratio=train_ratio)

print("Dataset split completed!")
# Out:
# ['0.jpg', '1.jpg', '10.jpg', '100.jpg', '101.jpg', '102.jpg', '103.jpg', '104.jpg', '105.jpg', '106.jpg', '107.jpg', '108.jpg', '109.jpg', '11.jpg', '110.jpg', '111.jpg', '112.jpg', '113.jpg', '114.jpg', '115.jpg', '116.jpg', '117.jpg', '118.jpg', '119.jpg', '12.jpg', '120.jpg', '121.jpg', '122.jpg', '123.jpg', '124.jpg', '125.jpg', '126.jpg', '127.jpg', '128.jpg', '129.jpg', '13.jpg', '130.jpg', '131.jpg', '132.jpg', '133.jpg', '134.jpg', '135.jpg', '136.jpg', '137.jpg', '138.jpg', '139.jpg', '14.jpg', '140.jpg', '141.jpg', '142.jpg', '143.jpg', '144.jpg', '145.jpg', '146.jpg', '147.jpg', '148.jpg', '149.jpg', '15.jpg', '150.jpg', '151.jpg', '152.jpg', '153.jpg', '154.jpg', '155.jpg', '156.jpg', '157.jpg', '158.jpg', '159.jpg', '16.jpg', '160.jpg', '161.jpg', '162.jpg', '163.jpg', '164.jpg', '165.jpg', '166.jpg', '167.jpg', '168.jpg', '169.jpg', '17.jpg', '170.jpg', '171.jpg', '172.jpg', '173.jpg', '174.jpg', '175.jpg', '176.jpg', '177.jpg', '178.jpg', '179.jpg', '18.jpg', '180.jpg'
# ...

# %%
import os

def check_dataset_structure(base_dir):
    """
    Checks if train/test folders and A/B subfolders exist,
    and prints the number of images in each.
    """
    for split in ["train", "test"]:
        for subfolder in ["A", "B"]:
            folder_path = os.path.join(base_dir, split, subfolder)
            if os.path.exists(folder_path):
                num_files = len([f for f in os.listdir(folder_path)
                                 if f.lower().endswith(('.png', '.jpg', '.jpeg'))])
                print(f"{folder_path}: exists, contains {num_files} image(s)")
            else:
                print(f"{folder_path}: MISSING!")

# Example usage:
output_dir = "/content/drive/MyDrive/MAI/Dissertation/CycleGAN_erik_linder/data/day2night"
check_dataset_structure(output_dir)
# Out:
# /content/drive/MyDrive/MAI/Dissertation/CycleGAN_erik_linder/data/day2night/train/A: exists, contains 417 image(s)
# /content/drive/MyDrive/MAI/Dissertation/CycleGAN_erik_linder/data/day2night/train/B: exists, contains 181 image(s)
# /content/drive/MyDrive/MAI/Dissertation/CycleGAN_erik_linder/data/day2night/test/A: exists, contains 105 image(s)
# /content/drive/MyDrive/MAI/Dissertation/CycleGAN_erik_linder/data/day2night/test/B: exists, contains 46 image(s)
